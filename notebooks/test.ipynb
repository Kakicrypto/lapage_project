# %%
import pandas as pd
import numpy as np
import sys
sys.path.append('../src')
from correlation import correlation_quanti_quanti

# %%
# Un DF avec des données qui ont du sens
df_propre = pd.DataFrame({
    'age': [25, 30, 35, 40, 45],
    'salaire': [2500.50, 3000.0, 3800.75, 4200.0, 5000.25],
    'score': [10, 15, 12, 18, 20]
})

# %%
pas_un_df = [1, 2, 3] # Une simple liste

# %%
df_mixte = pd.DataFrame({
    'nom': ['Quentin', 'Alice', 'Bob'],
    'age': [25, 30, 35]
    # C'est du type 'object' (String)
})
# Test : corelation_quanti_quanti(df_mixte, 'age', 'nom')
# -> Doit dire que 'nom' n'est pas au bon format.

# %%
correlation_quanti_quanti(df_propre,'age','score')
# Out:
# Validation réussie pour age et score.

# %%
correlation_quanti_quanti(pas_un_df,'col','col2')
# Out:
# Erreur: l'entrée [1, 2, 3] n'est pas un dataframe

# %%
correlation_quanti_quanti(df_mixte,'age','nom')
# Out:
# Erreur : La colonne 'nom' n'est pas numérique (object).
